# %%
import os
import time
from dotenv import load_dotenv
import json
import re
import random
import string
import traceback
import logging
import asyncio
import sys
import pandas as pd 
sys.path.append(os.path.abspath('..'))
from utilities import PostgresClient

from daytona import Daytona, DaytonaConfig, CreateSandboxFromSnapshotParams
from openai import AzureOpenAI
load_dotenv()

# Initialize the Daytona client

# print(os.getenv("DAYTONA_KEY"))
daytona = Daytona(DaytonaConfig(api_key=os.getenv("DAYTONA_KEY")))
# Create the Sandbox instance
chat_client = AzureOpenAI(
    api_key=os.getenv("GPT5OMINIKEY"),
    api_version=os.getenv("OPENAI_API_VERSION_GPT_5O"),
    azure_endpoint=os.getenv("GPT5OMINIENDPOINT"),
)
pg_client = PostgresClient(
    host=os.getenv('DB_HOST'),
    username=os.getenv('DB_USER'),
    password=os.getenv('DB_PASSWORD'),
    db_port=os.getenv('DB_PORT'),
    db_name=os.getenv('DB_NAME')
)
print("Daytona, PGClient, and AzureOpenAI clients initialized")
# Out:
# Daytona, PGClient, and AzureOpenAI clients initialized

# %%
sandbox = daytona.create()

# Run code securely inside the Sandbox
response = sandbox.process.code_run('print("Sum of 3 and 4 is " + str(3 + 4))')
if response.exit_code != 0:
    print(f"Error running code: {response.exit_code} {response.result}")
else:
    print(response.result)

# Clean up the Sandbox
sandbox.delete()
# Out:
# Sum of 3 and 4 is 7

# %%
def sample_large_text(text, max_chars=12000, num_samples=4):
    """Sample from the text to avoid hitting the max context window. Divided based on num_samples"""
    length = len(text)
    if length <= max_chars:
        return text
    
    sample_size = max_chars // num_samples
    samples = []
    
    # Distribute samples evenly across the text
    for i in range(num_samples):
        # Calculate the starting position as a percentage of total length
        # For 5 samples: 0%, 20%, 40%, 60%, 80%
        position_percent = i / num_samples
        start_pos = int(position_percent * length)
        
        # Make sure we don't go past the end
        end_pos = min(start_pos + sample_size, length)
        samples.append(text[start_pos:end_pos])
    
    return "\n\n... [content omitted] ...\n\n".join(samples)

def smart_json_sample(file_path_or_text, max_sample_items=3):
    """Parse JSON and create a structure summary with samples"""
    try:
        # Try to parse as JSON
        if os.path.exists(file_path_or_text):
            with open(file_path_or_text, 'r') as f:
                data = json.load(f)
        else:
            data = json.loads(file_path_or_text)
        
        # Find arrays that look like product/item lists
        def find_arrays(obj, path=""):
            arrays = []
            if isinstance(obj, dict):
                for key, value in obj.items():
                    new_path = f"{path}.{key}" if path else key
                    if isinstance(value, list) and len(value) > 0 and isinstance(value[0], dict):
                        # This looks like a data array
                        arrays.append((new_path, value))
                    else:
                        arrays.extend(find_arrays(value, new_path))
            elif isinstance(obj, list):
                for i, item in enumerate(obj):
                    arrays.extend(find_arrays(item, f"{path}[{i}]"))
            return arrays
        
        data_arrays = find_arrays(data)
        
        # Create summary
        summary = {
            "structure_info": f"JSON with {len(data_arrays)} data array(s) found",
            "arrays": []
        }
        
        for path, arr in data_arrays:
            summary["arrays"].append({
                "path": path,
                "total_items": len(arr),
                "sample_items": arr[:max_sample_items],
                "note": f"Array contains {len(arr)} total items"
            })
        
        return json.dumps(summary, indent=2), data_arrays
        
    except Exception as e:
        # Fallback to text sampling if not valid JSON
        return sample_large_text(file_path_or_text), []

# %%
import json
from datetime import datetime

test_path = "/Users/kappavi/Documents/Avi's Documents /Work/bb-daytona/test/sample2.json"
test_req = "item_name, item_id, price, UPC, image_url"

# Step 1: Get user inputs
print("=" * 60)
raw_data = input("What do you want parsed? (Enter raw text/JSON or provide a relative path to a file): ")
# check if raw_data is a path, else parse it litrelaly
print(f"Raw data sample: (determining if path or raw data): {raw_data[:100]}")
if os.path.exists(raw_data):
    sampled_data, data_arrays = smart_json_sample(raw_data, max_sample_items=3) # pass this to LLM 
    with open(raw_data, 'r') as file:
        raw_file_content = file.read() # this is what we pass to teh parser
        # raw_data = raw_data[:3000] # truncate super loong inputs 
        # raw_data = sample_large_text(raw_data)
        
    #     print(f"Reading from inputted file: {raw_data[:100]}")
    # Extract the actual path to the data array
    data_path_info = ""
    if data_arrays:
        paths = [f"  - {path}: {len(arr)} items" for path, arr in data_arrays]
        data_path_info = f"\n\nData location(s) in JSON:\n" + "\n".join(paths)
    
    print(f"✅ Parsed JSON structure with sample data{data_path_info}")
else:
    raw_file_content = raw_data
    sampled_data = sample_large_text(raw_data)
    data_array = []
    print(f"Parsing raw data: {raw_data[:100]}")
expected_fields = input("What fields do you expect? (e.g., item_name, item_id, price, is_on_promotion): ")
print("=" * 60)

if data_arrays:
    array_hints = "\n".join([f"- {path} contains {len(arr)} items" for path, arr in data_arrays])

# Step 2: Use AI to generate parser code dynamically
prompt = f"""Generate Python code that will parse the following raw data and extract these field informations (They may not follow the exact same name or form,
    but the general idea should be the same): {expected_fields}
    For example, if the user was item_id, find a field that assigns some sort of id to an item.

    Data structure with samples:
    {sampled_data}

    Some potential data locations:
    {array_hints}

    Requirements:
    - The JSON data will be provided in a variable called 'raw_json_string' as a string
    - Navigate to the correct array path in the JSON
    - Extract the requested fields: {expected_fields}
    - Return a list of dictionaries with all items from the array
    - Handle missing fields gracefully (use None)
    - Print the result as JSON using json.dumps()
    - Keep the code simple and direct

    Only output the Python code, no explanations."""

time_start = time.time()
response = chat_client.chat.completions.create(
    model='gpt-5-mini',
    messages=[
        {"role": "system", "content": "You are a Python code generator. Output only valid Python code without any markdown formatting or explanations."},
        {"role": "user", "content": prompt}
    ]
)
time_end = time.time()
generated_code = response.choices[0].message.content.strip()
# Remove markdown code blocks if present
generated_code = re.sub(r'^```python\n|^```\n|```$', '', generated_code, flags=re.MULTILINE).strip()

print("\n📝 Generated Parser Code:")
print("-" * 60)
print(generated_code)
print("-" * 60)
print(f"Time taken to dynamically generate parser code: {time_end - time_start} seconds")

# Step 3: Run the parser in Daytona sandbox
print("\n🚀 Running parser in Daytona sandbox...")
params = CreateSandboxFromSnapshotParams(language="python")
sandbox = daytona.create(params)

try:
    time_start = time.time()
    escaped_json_string = json.dumps(raw_file_content)
    
    full_code = f"""import json

# Load the raw JSON string
raw_json_string = json.loads({escaped_json_string})

{generated_code}
"""
    result = sandbox.process.code_run(full_code)
    
    if result.exit_code != 0:
        print(f"❌ Error running parser: {result.exit_code}")
        print(result.result)
    else:
        print("\n✅ Parser executed successfully!")
        print("\n📦 Parsed Output:")
        print("=" * 60)
        # Try to pretty print if it's valid JSON
        try:
            parsed_json = json.loads(result.result.strip())
            print(json.dumps(parsed_json, indent=2))
        except:
            print(result.result)
        print("=" * 60)
        time_end = time.time()
        print(f"Time taken to parse data: {time_end - time_start} seconds")
finally:
    # Step 4: Clean up
    sandbox.delete()
    print("\n🧹 Sandbox cleaned up")

# write teh outpout to a file 
today_time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
output_file = f"output_{today_time}.json"
with open(output_file, 'w') as f:
    json.dump(parsed_json, f, indent=2)
print(f"Output written to {output_file}")
# Out:
# ============================================================
# Raw data sample: (determining if path or raw data): /Users/kappavi/Documents/Avi's Documents /Work/bb-daytona/test/sample2.json
# ✅ Parsed JSON structure with sample data
#
# Data location(s) in JSON:
#   - pageProps.data.meta.state.refinements: 1 items
#   - pageProps.data.facets: 3 items
#   - pageProps.data.results: 60 items
#   - pageProps.data.breadcrumb: 1 items
# ============================================================
#
# 📝 Generated Parser Code:
# ------------------------------------------------------------
# import json
# import re
# from collections import deque
#
# def find_product_list(obj):
#     """
#     Recursively search for a list of dicts that looks like a product list.
#     Heuristics: list of dicts where at least one dict has keys like 'name', 'slug', 'regularPrice' or 'imageThumbnail'.
#     """
#     signatures = {"name", "slug", "regularPrice", "imageThumbnail", "price", "title", "image"}
#     visited = set()
#     queue = deque([obj])
#     while queue:
#         current = queue.popleft()
#         cid = id(current)
#         if cid in visited:
#             continue
#         visited.add(cid)
#         if isinstance(current, list):
#             if current and all(isinstance(i, dict) for i in current):
#                 # check if any item has signature keys
#                 for item in current:
#                     if any(k in item for k in signatures) or any(k.lower() in signatures for k in item):
#                         return current
#             # also explore elements
#             for elem in current:
#                 if isinstance(elem, (dict, list)):
#                     queue.append(elem)
#         elif isinstance(current, dict):
#             # check for direct results path keys
#             if ("pageProps" in current and isinstance(current.get("pageProps"), dict)):
#                 dp = current.get("pageProps", {}).get("data")
#                 if isinstance(dp, dict) and isinstance(dp.get("results"), list):
#                     return dp.get("results")
#             for v in current.values():
#                 if isinstance(v, (dict, list)):
#                     queue.append(v)
#     return None
#
# def parse_price(val):
#     if val is None:
#         return None
#     if isinstance(val, (int, float)):
#         return float(val)
#     if isinstance(val, str):
#         # remove currency symbols and non-numeric except dot and minus
#         txt = val.strip()
#         # common formats: "$12.99", "12.99", "USD 12.99"
#         m = re.search(r"[-+]?[0-9]+(?:[,0-9]*[0-9])?(?:\.[0-9]+)?", txt.replace(',', ''))
#         if m:
#             try:
#                 return float(m.group(0))
#             except:
#                 return None
#         return None
#     if isinstance(val, dict):
#         # common nested keys
#         for k in ("amount", "value", "price", "regularPrice", "salePrice"):
#             if k in val:
#                 return parse_price(val[k])
#         # try any numeric value in dict
#         for v in val.values():
#             if isinstance(v, (int, float, str, dict)):
#                 p = parse_price(v)
#                 if p is not None:
#                     return p
#     return None
#
# def find_first_key(obj, candidate_keys):
#     """
#     Recursively find the first occurrence of any candidate key (case-insensitive) in obj.
#     Returns the value or None.
#     """
#     if obj is None:
#         return None
#     candidate_lowers = {k.lower() for k in candidate_keys}
#     visited = set()
#     queue = deque([obj])
#     while queue:
#         current = queue.popleft()
#         cid = id(current)
#         if cid in visited:
#             continue
#         visited.add(cid)
#         if isinstance(current, dict):
#             for k, v in current.items():
#                 if k.lower() in candidate_lowers:
#                     return v
#             for v in current.values():
#                 if isinstance(v, (dict, list)):
#                     queue.append(v)
#         elif isinstance(current, list):
#             for elem in current:
#                 if isinstance(elem, (dict, list)):
#                     queue.append(elem)
#     return None
#
# def extract_field(item, name_keys):
#     # check direct keys first (case sensitive common names)
#     for k in name_keys:
#         if k in item:
#             return item[k]
#     # check case-insensitive direct keys
#     lower_map = {k.lower(): k for k in item.keys()}
#     for k in name_keys:
#         lk = k.lower()
#         if lk in lower_map:
#             return item[lower_map[lk]]
#     # fallback: search nested
#     return find_first_key(item, name_keys)
#
# # Start processing
# try:
#     data = json.loads(raw_json_string)
# except Exception:
#     # If raw_json_string is not valid JSON, print empty list
#     print(json.dumps([]))
#     raise SystemExit
#
# # Try direct expected path first
# products = None
# if isinstance(data, dict):
#     products = data.get("pageProps", {}).get("data", {}).get("results")
# if not isinstance(products, list):
#     products = find_product_list(data)
#
# if not isinstance(products, list):
#     # nothing found, return empty
#     print(json.dumps([]))
#     raise SystemExit
#
# results = []
# for item in products:
#     if not isinstance(item, dict):
#         # skip non-dict entries
#         continue
#
#     # Define candidate keys
#     name_keys = ['name', 'title', 'label', 'productName', 'item_name']
#     id_keys = ['id', 'productId', 'itemId', 'sku', 'asin', 'slug', 'gtin', 'item_id']
#     price_keys = ['price', 'regularPrice', 'salePrice', 'listPrice', 'amount', 'value']
#     upc_keys = ['upc', 'UPC', 'barcode', 'gtin', 'upc_code']
#     image_keys = ['image', 'imageUrl', 'image_url', 'imageThumbnail', 'image_thumbnail', 'thumbnail', 'picture', 'img', 'imageUrlSmall']
#
#     # Extract fields
#     item_name = extract_field(item, name_keys)
#     item_id = extract_field(item, id_keys)
#     # For price, attempt parse
#     raw_price = extract_field(item, price_keys)
#     price = parse_price(raw_price)
#     # Try finding UPC (case-insensitive)
#     upc = extract_field(item, upc_keys)
#     # Image
#     image_url = extract_field(item, image_keys)
#
#     # Normalize UPC if it's nested or dict
#     if isinstance(upc, dict):
#         upc = find_first_key(upc, upc_keys)
#     # Normalize image if dict
#     if isinstance(image_url, dict):
#         image_url = find_first_key(image_url, image_keys)
#
#     # Ensure strings for names and ids, else None
#     if isinstance(item_name, (int, float)):
#         item_name = str(item_name)
#     if item_name is None:
#         item_name = None
#     if isinstance(item_id, (int, float)):
#         item_id = str(item_id)
#     if item_id is None:
#         item_id = None
#     if isinstance(upc, (int, float)):
#         upc = str(upc)
#
#     results.append({
#         "item_name": item_name,
#         "item_id": item_id,
#         "price": price,
#         "UPC": upc if upc is not None else None,
#         "image_url": image_url if image_url is not None else None
#     })
#
# print(json.dumps(results, ensure_ascii=False))
# ------------------------------------------------------------
# Time taken to dynamically generate parser code: 33.26100516319275 seconds
#
# 🚀 Running parser in Daytona sandbox...
#
# 🧹 Sandbox cleaned up
# ---------------------------------------------------------------------------
# DaytonaError                              Traceback (most recent call last)
# Cell In[7], line 95
#      86     escaped_json_string = json.dumps(raw_file_content)
#      88     full_code = f"""import json
#      89
#      90 # Load the raw JSON string
#    (...)     93 {generated_code}
#      94 """
# ---> 95     result = sandbox.process.code_run(full_code)
#      97     if result.exit_code != 0:
#      98         print(f"❌ Error running parser: {result.exit_code}")
#
# File ~/Documents/Avi's Documents /Work/bb-daytona/.venv/lib/python3.12/site-packages/daytona/_sync/process.py:238, in Process.code_run(self, code, params, timeout)
#     172 """Executes code in the Sandbox using the appropriate language runtime.
#     173
#     174 Args:
#    (...)    235     ```
#     236 """
#     237 command = self._code_toolbox.get_run_command(code, params)
# --> 238 return self.exec(command, env=params.env if params else None, timeout=timeout)
#
# File ~/Documents/Avi's Documents /Work/bb-daytona/.venv/lib/python3.12/site-packages/daytona/_utils/errors.py:60, in intercept_errors.<locals>.decorator.<locals>.sync_wrapper(*args, **kwargs)
#      58     return func(*args, **kwargs)
#      59 except Exception as e:
# ---> 60     process_n_raise_exception(e)
#
# File ~/Documents/Avi's Documents /Work/bb-daytona/.venv/lib/python3.12/site-packages/daytona/_utils/errors.py:39, in intercept_errors.<locals>.decorator.<locals>.process_n_raise_exception(e)
#      37     if isinstance(e, (NotFoundException, NotFoundExceptionAsync)):
#      38         raise DaytonaNotFoundError(f"{message_prefix}{msg}") from None
# ---> 39     raise DaytonaError(f"{message_prefix}{msg}") from None
#      41 msg = f"{message_prefix}{str(e)}" if message_prefix else str(e)
#      42 raise DaytonaError(msg)
#
# DaytonaError: Failed to execute command: Missing parameter name at 6: https://git.new/pathToRegexpError
